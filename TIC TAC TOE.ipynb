# %%
import tkinter
from tkinter import *
from tkinter import messagebox
def disables_all_buttons():
    b1.config(state=DISABLED)
    b2.config(state=DISABLED)
    b3.config(state=DISABLED)
    b4.config(state=DISABLED)
    b5.config(state=DISABLED)
    b6.config(state=DISABLED)
    b7.config(state=DISABLED)
    b8.config(state=DISABLED)
    b9.config(state=DISABLED)


clicked = True
count = 0
def show_winn():
    global winner
    winner = False

    if b1['text'] == 'X' and b2['text'] == 'X' and b3['text'] == 'X':
        b1.config(bg = 'red')
        b2.config(bg = 'red')
        b3.config(bg = 'red')
        winner = True
        messagebox.showinfo('tic tac toe','Congo X is winner!')
        disables_all_buttons()
    elif b4['text'] == 'X' and b5['text'] == 'X' and b6['text'] == 'X':
        b4.config(bg = 'red')
        b5.config(bg = 'red')
        b6.config(bg = 'red')
        winner = True
        messagebox.showinfo('tic tac toe','Congo X is winner!')
        disables_all_buttons()
    elif b7['text'] == 'X' and b8['text'] == 'X' and b9['text'] == 'X':
        b7.config(bg = 'red')
        b8.config(bg = 'red')
        b9.config(bg = 'red')
        winner = True
        messagebox.showinfo('tic tac toe','Congo X is winner!')
        disables_all_buttons()
    elif b1['text'] == 'X' and b4['text'] == 'X' and b7['text'] == 'X':
        b1.config(bg = 'red')
        b4.config(bg = 'red')
        b7.config(bg = 'red')
        winner = True
        messagebox.showinfo('tic tac toe','Congo X is winner!')
        disables_all_buttons()
    elif b5['text'] == 'X' and b2['text'] == 'X' and b8['text'] == 'X':
        b5.config(bg = 'red')
        b2.config(bg = 'red')
        b8.config(bg = 'red')
        winner = True
        messagebox.showinfo('tic tac toe','Congo X is winner!')
        disables_all_buttons()
    elif b6['text'] == 'X' and b9['text'] == 'X' and b3['text'] == 'X':
        b6.config(bg = 'red')
        b9.config(bg = 'red')
        b3.config(bg = 'red')
        winner = True
        messagebox.showinfo('tic tac toe','Congo X is winner!')
        disables_all_buttons()
    elif b1['text'] == 'X' and b5['text'] == 'X' and b9['text'] == 'X':
        b1.config(bg = 'red')
        b5.config(bg = 'red')
        b9.config(bg = 'red')
        winner = True
        messagebox.showinfo('tic tac toe','Congo X is winner!')
        disables_all_buttons()
    elif b5['text'] == 'X' and b7['text'] == 'X' and b3['text'] == 'X':
        b5.config(bg = 'red')
        b7.config(bg = 'red')
        b3.config(bg = 'red')
        winner = True
        messagebox.showinfo('tic tac toe','Congo X is winner!')
        disables_all_buttons()
    # NOW FOR O
    elif b1['text'] == 'O' and b2['text'] == 'O' and b3['text'] == 'O':
        b1.config(bg = 'blue')
        b2.config(bg = 'blue')
        b3.config(bg = 'blue')
        winner = True
        messagebox.showinfo('tic tac toe','Congo 0 is winner!')
        disables_all_buttons()
    elif b4['text'] == 'O' and b5['text'] == 'O' and b6['text'] == 'O':
        b4.config(bg = 'blue')
        b5.config(bg = 'blue')
        b6.config(bg = 'blue')
        winner = True
        messagebox.showinfo('tic tac toe','Congo O is winner!')
        disables_all_buttons()
    elif b7['text'] == 'O' and b8['text'] == 'O' and b9['text'] == 'O':
        b7.config(bg = 'blue')
        b8.config(bg = 'blue')
        b9.config(bg = 'blue')
        winner = True
        messagebox.showinfo('tic tac toe','Congo O is winner!')
        disables_all_buttons()
    elif b1['text'] == 'O' and b4['text'] == 'O' and b7['text'] == 'O':
        b1.config(bg = 'blue')
        b4.config(bg = 'blue')
        b7.config(bg = 'blue')
        winner = True
        messagebox.showinfo('tic tac toe','Congo O is winner!')
        disables_all_buttons()
    elif b5['text'] == 'O' and b2['text'] == 'O' and b8['text'] == 'O':
        b5.config(bg = 'blue')
        b2.config(bg = 'blue')
        b8.config(bg = 'blue')
        winner = True
        messagebox.showinfo('tic tac toe','Congo O is winner!')
        disables_all_buttons()
    elif b6['text'] == 'O' and b9['text'] == 'O' and b3['text'] == 'O':
        b6.config(bg = 'blue')
        b9.config(bg = 'blue')
        b3.config(bg = 'blue')
        winner = True
        messagebox.showinfo('tic tac toe','Congo O is winner!')
        disables_all_buttons()
    elif b1['text'] == 'O' and b5['text'] == 'O' and b9['text'] == 'O':
        b1.config(bg = 'blue')
        b5.config(bg = 'blue')
        b9.config(bg = 'blue')
        winner = True
        messagebox.showinfo('tic tac toe','Congo O is winner!')
        disables_all_buttons()
    elif b5['text'] == 'O' and b7['text'] == 'O' and b3['text'] == 'O':
        b5.config(bg = 'blue')
        b7.config(bg = 'blue')
        b3.config(bg = 'blue')
        winner = True
        messagebox.showinfo('tic tac toe','Congo O is winner!')
        disables_all_buttons()
    if count == 9 and winner == False:
        messagebox.showinfo('tic tac toe','it is a tie' )

def click():
    global clicked, count
    if b1['text'] == '' and clicked == True:
        b1['text']= 'X'
        clicked = False
        count += 1
        show_winn()
    elif b1['text'] == '' and clicked == False:
        b1['text']= 'O'
        clicked = True
        count += 1
        show_winn()
    else:
        messagebox.showerror('tic tac toe','limit exceed')

def click2():
    global clicked, count
    if b2['text'] == '' and clicked == True:
        b2['text']= 'X'
        clicked = False
        count += 1
        show_winn()
    elif b2['text'] == '' and clicked == False:
        b2['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')
def click3():
    global clicked, count
    if b3['text'] == '' and clicked == True:
        b3['text']= 'X'
        clicked = False
        count += 1
        show_winn()

    elif b3['text'] == '' and clicked == False:
        b3['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')
def click4():
    global clicked, count
    if b4['text'] == '' and clicked == True:
        b4['text']= 'X'
        clicked = False
        count += 1
        show_winn()

    elif b4['text'] == '' and clicked == False:
        b4['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')
def click5():
    global clicked, count
    if b5['text'] == '' and clicked == True:
        b5['text']= 'X'
        clicked = False
        count += 1
        show_winn()

    elif b5['text'] == '' and clicked == False:
        b5['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')
def click6():
    global clicked, count
    if b6['text'] == '' and clicked == True:
        b6['text']= 'X'
        clicked = False
        count += 1
        show_winn()

    elif b6['text'] == '' and clicked == False:
        b6['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')
def click6():
    global clicked, count
    if b6['text'] == '' and clicked == True:
        b6['text']= 'X'
        clicked = False
        count += 1
        show_winn()

    elif b6['text'] == '' and clicked == False:
        b6['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')
def click7():
    global clicked, count
    if b7['text'] == '' and clicked == True:
        b7['text']= 'X'
        clicked = False
        count += 1
        show_winn()

    elif b7['text'] == '' and clicked == False:
        b7['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')
def click8():
    global clicked, count
    if b8['text'] == '' and clicked == True:
        b8['text']= 'X'
        clicked = False
        count += 1
        show_winn()

    elif b8['text'] == '' and clicked == False:
        b8['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')
def click9():
    global clicked, count
    if b9['text'] == '' and clicked == True:
        b9['text']= 'X'
        clicked = False
        count += 1
        show_winn()

    elif b9['text'] == '' and clicked == False:
        b9['text']= 'O'
        clicked = True
        count += 1
        show_winn()

    else:
        messagebox.showerror('tic tac toe','limit exceed')

root = Tk()
root.geometry('275x550')
img = tkinter.PhotoImage(file="C:\\Users\\vijit kumar\\OneDrive\\Desktop\\download.png")
root.iconphoto(root,img)
root.title('TIC TAC TOE')
def reset():
    global b1,b2,b3,b4,b5,b6,b7,b8,b9
    global clicked,count
    clicked = True
    count = 0
    b1 = Button(root,text = '',width=12,height=12,command=click)
    b2 = Button(root,text = '',width=12,height=12,command=click2)
    b3 = Button(root,text = '',width=12,height=12,command=click3)
    b4 = Button(root,text = '',width=12,height=12,command=click4)
    b5 = Button(root,text = '',width=12,height=12,command=click5)
    b6 = Button(root,text = '',width=12,height=12,command=click6)
    b7 = Button(root,text = '',width=12,height=12,command=click7)
    b8 = Button(root,text = '',width=12,height=12,command=click8)
    b9 = Button(root,text = '',width=12,height=12,command=click9)
    #B10 = Button(root,text = 'check winner',command=show_winn)
    b1.grid(row = 0 , column= 0)
    b2.grid(row = 0  , column= 1)
    b3.grid(row = 0  , column= 2)
    b4.grid(row = 1  , column= 0)
    b5.grid(row = 1  , column= 1)
    b6.grid(row = 1  , column= 2)
    b7.grid(row = 2  , column= 0)
    b8.grid(row = 2  , column= 1)
    b9.grid(row = 2  , column= 2)
#B10.grid(row = 3, column= 1)
my_menu = Menu(root)
root.config(menu=my_menu)
option_menu = Menu(my_menu,tearoff=False)
my_menu.add_cascade(label = 'Options',menu = option_menu)
option_menu.add_cascade(label = 'Reset game',command=reset)
reset()
root.resizable(False,False)
root.config(bg = 'black')
root.mainloop()
